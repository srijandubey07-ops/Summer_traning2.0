# %% [markdown]
# <a href="https://colab.research.google.com/github/srijandubey07-ops/Summer_traning2.0/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/Zomato-data-.csv")
df.head(10)
df.columns
df.info()
df.describe()

df[["name", "online_order"]]      # Multiple columns

df["name"]

# Clean the 'rate' column by removing '/5' and then convert to numeric
df["rate"] = df["rate"].astype(str).str.split('/').str[0]
df["rate"] = pd.to_numeric(df["rate"])

df[df["rate"] > 3.0]              # Single condition
df["name"]
df['rate'] = pd.to_numeric(df['rate'])
df[(df['listed_in(type)'] == 'Dining') & (df['book_table'] == 'Yes')]
df.sort_values("votes" , ascending=False)
df.rename(columns= {"name" : "customer_name"} , inplace= True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB
